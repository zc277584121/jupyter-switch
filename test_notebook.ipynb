# %% [markdown]
# # Test NotebookThis is a test notebook to verify uvx jupyter-switch conversion.

# %%
print("Hello, World!")
x = 42
print(f"The answer is {x}")

# %% [markdown]
# ## More ContentThis is another markdown cell with some **bold** and *italic* text.

# %%
import math
result = math.sqrt(16)
print(f"Square root of 16 is {result}")
